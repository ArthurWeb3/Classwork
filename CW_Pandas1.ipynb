# %%
#Figure 1: Import Data
import pandas as pd 
xl = pd.ExcelFile('/content/TableauSalesData.xlsx')
SalesData = xl.parse('Orders')
#Print first 10 rows in dataframe
print(SalesData.head(10))
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    4919  CA-2017-160304 2017-01-02 2017-01-07  Standard Class    BM-11575
# 1    4920  CA-2017-160304 2017-01-02 2017-01-07  Standard Class    BM-11575
# 2    3074  CA-2017-125206 2017-01-03 2017-01-05     First Class    LR-16915
# 3    8604  US-2017-116365 2017-01-03 2017-01-08  Standard Class    CA-12310
# 4    8605  US-2017-116365 2017-01-03 2017-01-08  Standard Class    CA-12310
# 5    8606  US-2017-116365 2017-01-03 2017-01-08  Standard Class    CA-12310
# 6    9494  CA-2017-105207 2017-01-03 2017-01-08  Standard Class    BO-11350
# 7    9495  CA-2017-105207 2017-01-03 2017-01-08  Standard Class    BO-11350
# 8    2898  US-2017-164630 2017-01-04 2017-01-09  Standard Class    EB-13975
# 9    5868  CA-2017-158211 2017-01-04 2017-01-08  Standard Class    BP-11185
#
#        Customer Name    Segment        Country          City  ... Postal Code  \
# 0      Brendan Murry  Corporate  United States  Gaithersburg  ...       20877
# 1      Brendan Murry  Corporate  United States  Gaithersburg  ...       20877
# 2       Lena Radford   Consumer  United States   Los Angeles  ...       90045
# 3  Christine Abelman  Corporate  United States   San Antonio  ...       78207
# 4  Christine Abelman  Corporate  United States   San Antonio  ...       78207
# 5  Christine Abelman  Corporate  United States   San Antonio  ...       78207
# 6      Bill Overfelt  Corporate  United States  Broken Arrow  ...       74012
# 7      Bill Overfelt  Corporate  United States  Broken Arrow  ...       74012
# 8         Erica Bern  Corporate  United States     Charlotte  ...       28205
# 9       Ben Peterman  Corporate  United States  Philadelphia  ...       19143
#
#     Region       Product ID         Category Sub-Category  \
# 0     East  FUR-BO-10004709        Furniture    Bookcases
# 1     East  TEC-PH-10000455       Technology       Phones
# 2     West  OFF-ST-10003692  Office Supplies      Storage
# 3  Central  TEC-AC-10002217       Technology  Accessories
# 4  Central  TEC-AC-10002942       Technology  Accessories
# 5  Central  TEC-PH-10002890       Technology       Phones
# 6  Central  FUR-TA-10000617        Furniture       Tables
# 7  Central  OFF-BI-10004364  Office Supplies      Binders
# 8    South  TEC-CO-10000971       Technology      Copiers
# 9     East  OFF-AR-10004078  Office Supplies          Art
#
#                                         Product Name     Sales  Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   173.940         3
# 1                                        GE 30522EE2   231.980         2
# 2  Recycled Steel Personal File for Hanging File ...   114.460         2
# 3                Imation Clip USB flash drive - 8 GB    30.080         2
# 4  WD My Passport Ultra 1TB Portable External Har...   165.600         3
# 5                      AT&T 17929 Lendline Telephone   180.960         5
# 6  Hon Practical Foundations 30 x 60 Training Tab...  1592.850         7
# 7                            Storex Dura Pro Binders    11.880         2
# 8           Hewlett Packard 310 Color Digital Copier   959.968         4
# 9                                         Newell 312     4.672         1
#
#    Discount    Profit
# 0       0.0   38.2668
# 1       0.0   67.2742
# 2       0.0   28.6150
# 3       0.2   -5.2640
# 4       0.2   -6.2100
# 5       0.2   13.5720
# 6       0.0  350.4270
# 7       0.0    5.3460
# 8       0.2  119.9960
# 9       0.2    0.5840
#
# [10 rows x 21 columns]

# %%
#Columns Function
print(SalesData.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#Desccribe for data descriptive statistics
print(SalesData.describe())

# %%
#.unique to get a list of unique values in a column
Categories = SalesData["Category"].unique()
print(Categories)
# Out:
# ['Furniture' 'Technology' 'Office Supplies']

# %%
#Modify .unique code to see values in other columns
Segment = SalesData["Segment"].unique()
print(Segment)
# Out:
# ['Corporate' 'Consumer' 'Home Office']

# %%
#Part 4: Group, Sum, Sort
SubCatProfits = SalesData[['Sub-Category', 'Profit', 'Sales']]
print(SubCatProfits)
# Out:
#      Sub-Category    Profit    Sales
# 0       Bookcases   38.2668  173.940
# 1          Phones   67.2742  231.980
# 2         Storage   28.6150  114.460
# 3     Accessories   -5.2640   30.080
# 4     Accessories   -6.2100  165.600
# ...           ...       ...      ...
# 9989      Binders  167.8080  364.800
# 9990      Storage  -26.7204  152.688
# 9991    Fasteners    0.5668    3.488
# 9992     Supplies   -1.3248    5.888
# 9993      Binders   52.3800  116.400
#
# [9994 rows x 3 columns]

# %%
#Groupby, Sum, and sort_values
TotalSubCatProfits = SubCatProfits.groupby(by = 'Sub-Category').sum().sort_values(by = 'Profit')
print(TotalSubCatProfits)
# Out:
#                   Profit        Sales
# Sub-Category
# Tables       -17725.4811  206965.5320
# Bookcases     -3472.5560  114879.9963
# Supplies      -1189.0995   46673.5380
# Fasteners       949.5182    3024.2800
# Machines       3384.7569  189238.6310
# Labels         5546.2540   12486.3120
# Art            6527.7870   27118.7920
# Envelopes      6964.1767   16476.4020
# Furnishings   13059.1436   91705.1640
# Appliances    18138.0054  107532.1610
# Storage       21278.8264  223843.6080
# Chairs        26590.1663  328449.1030
# Binders       30221.7633  203412.7330
# Paper         34053.5693   78479.2060
# Accessories   41936.6357  167380.3180
# Phones        44515.7306  330007.0540
# Copiers       55617.8249  149528.0300

# %%
#Category, profit and sales
CategoryProfitSales = SalesData[['Category', 'Profit', 'Sales']].groupby("Category").sum().sort_values(by = 'Profit')
display(CategoryProfitSales)
# Out:
#                       Profit        Sales
# Category
# Furniture         18451.2728  741999.7953
# Office Supplies  122490.8008  719047.0320
# Technology       145454.9481  836154.0330

# %%
#Multilevel grouping category and sub-category
CategoryProfitSales = SalesData[['Category', 'Sub-Category', 'Profit', 'Sales']]
TotalCatSubCat = CategoryProfitSales.groupby(by=['Category', 'Sub-Category']).sum()
print(TotalCatSubCat)
# Out:
#                                   Profit        Sales
# Category        Sub-Category
# Furniture       Bookcases     -3472.5560  114879.9963
#                 Chairs        26590.1663  328449.1030
#                 Furnishings   13059.1436   91705.1640
#                 Tables       -17725.4811  206965.5320
# Office Supplies Appliances    18138.0054  107532.1610
#                 Art            6527.7870   27118.7920
#                 Binders       30221.7633  203412.7330
#                 Envelopes      6964.1767   16476.4020
#                 Fasteners       949.5182    3024.2800
#                 Labels         5546.2540   12486.3120
#                 Paper         34053.5693   78479.2060
#                 Storage       21278.8264  223843.6080
#                 Supplies      -1189.0995   46673.5380
# Technology      Accessories   41936.6357  167380.3180
#                 Copiers       55617.8249  149528.0300
#                 Machines       3384.7569  189238.6310
#                 Phones        44515.7306  330007.0540

# %%
#Using .loc function to find rows containing specific values + filter example
JustTables = SalesData.loc[SalesData['Sub-Category'] == 'Tables'] 
display(JustTables.head(10))
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 6      9494  CA-2017-105207 2017-01-03 2017-01-08  Standard Class    BO-11350
# 37     3236  CA-2017-140746 2017-01-15 2017-01-15        Same Day    RC-19825
# 69     9359  CA-2017-168046 2017-01-25 2017-01-28    Second Class    JD-15895
# 82     8927  CA-2017-168032 2017-01-30 2017-02-03  Standard Class    DF-13135
# 113    8144  CA-2017-100993 2017-02-05 2017-02-10  Standard Class    AZ-10750
# 130    7813  CA-2017-134334 2017-02-14 2017-02-15     First Class    DK-13090
# 172    1083  US-2017-143819 2017-03-01 2017-03-05  Standard Class    KD-16270
# 183    4003  CA-2017-145730 2017-03-03 2017-03-08  Standard Class    CC-12220
# 204    8985  CA-2017-110898 2017-03-06 2017-03-12  Standard Class    LC-16870
# 233    1462  US-2017-128902 2017-03-11 2017-03-15  Standard Class    MB-18085
#
#         Customer Name    Segment        Country           City  ...  \
# 6       Bill Overfelt  Corporate  United States   Broken Arrow  ...
# 37        Roy Collins   Consumer  United States      Fairfield  ...
# 69   Jonathan Doherty  Corporate  United States  New York City  ...
# 82     David Flashing   Consumer  United States       Rockford  ...
# 113      Annie Zypern   Consumer  United States      San Diego  ...
# 130         Dave Kipp   Consumer  United States        Clinton  ...
# 172     Karen Daniels   Consumer  United States        Yonkers  ...
# 183      Chris Cortes   Consumer  United States    San Antonio  ...
# 204     Lena Cacioppo   Consumer  United States        Chicago  ...
# 233        Mick Brown   Consumer  United States       Vineland  ...
#
#     Postal Code   Region       Product ID   Category Sub-Category  \
# 6         74012  Central  FUR-TA-10000617  Furniture       Tables
# 37         6824     East  FUR-TA-10002903  Furniture       Tables
# 69        10024     East  FUR-TA-10001095  Furniture       Tables
# 82        61107  Central  FUR-TA-10004256  Furniture       Tables
# 113       92037     West  FUR-TA-10001095  Furniture       Tables
# 130       20735     East  FUR-TA-10002356  Furniture       Tables
# 172       10701     East  FUR-TA-10001095  Furniture       Tables
# 183       78207  Central  FUR-TA-10004915  Furniture       Tables
# 204       60623  Central  FUR-TA-10000849  Furniture       Tables
# 233        8360     East  FUR-TA-10001095  Furniture       Tables
#
#                                           Product Name     Sales  Quantity  \
# 6    Hon Practical Foundations 30 x 60 Training Tab...  1592.850         7
# 37             Bevis Round Bullnose 29" High Table Top   181.797         1
# 69                  Chromcraft Round Conference Tables   313.722         3
# 82   Bretford “Just In Time” Height-Adjustable Mult...   626.100         3
# 113                 Chromcraft Round Conference Tables   557.728         4
# 130                 Bevis Boat-Shaped Conference Table   550.431         3
# 172                 Chromcraft Round Conference Tables   836.592         8
# 183  Office Impressions End Table, 20-1/2"H x 24"W ...   637.896         3
# 204                Bevis Rectangular Conference Tables   145.980         2
# 233                 Chromcraft Round Conference Tables   244.006         2
#
#      Discount    Profit
# 6         0.0  350.4270
# 37        0.3  -15.5826
# 69        0.4  -99.3453
# 82        0.5 -538.4460
# 113       0.2    6.9716
# 130       0.3  -47.1798
# 172       0.4 -264.9208
# 183       0.3 -127.5792
# 204       0.5  -99.2664
# 233       0.3  -31.3722
#
# [10 rows x 21 columns]

# %%
#locate justbookcases, 'JustBookcases'
JustBookcases = SalesData.loc[SalesData['Sub-Category'] == 'Bookcases'] 
display(JustBookcases.head(10))
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0      4919  CA-2017-160304 2017-01-02 2017-01-07  Standard Class    BM-11575
# 17     6851  US-2017-100461 2017-01-08 2017-01-12  Standard Class    JO-15145
# 52     2472  US-2017-135923 2017-01-22 2017-01-28  Standard Class    CM-11935
# 78     7566  US-2017-166660 2017-01-30 2017-02-01    Second Class    TB-21250
# 104    1387  US-2017-108504 2017-02-05 2017-02-05        Same Day    PP-18955
# 224    1876  US-2017-112977 2017-03-10 2017-03-16  Standard Class    CJ-12010
# 265    3929  CA-2017-162082 2017-03-14 2017-03-17     First Class    JS-15880
# 287    2226  CA-2017-106383 2017-03-19 2017-03-21    Second Class    BT-11440
# 307    9130  CA-2017-130911 2017-03-24 2017-03-26    Second Class    DC-12850
# 329    6382  CA-2017-127236 2017-03-29 2017-04-02  Standard Class    TB-21595
#
#        Customer Name      Segment        Country          City  ...  \
# 0      Brendan Murry    Corporate  United States  Gaithersburg  ...
# 17     Jack O'Briant    Corporate  United States      Franklin  ...
# 52     Carlos Meador     Consumer  United States  Fayetteville  ...
# 78      Tim Brockman     Consumer  United States       Seattle  ...
# 104       Paul Prost  Home Office  United States        Smyrna  ...
# 224  Caroline Jumper     Consumer  United States    Long Beach  ...
# 265   John Stevenson     Consumer  United States     Harlingen  ...
# 287    Bobby Trafton     Consumer  United States     Littleton  ...
# 307     Dan Campbell     Consumer  United States     Cleveland  ...
# 329   Troy Blackwell     Consumer  United States   Springfield  ...
#
#     Postal Code   Region       Product ID   Category Sub-Category  \
# 0         20877     East  FUR-BO-10004709  Furniture    Bookcases
# 17        53132  Central  FUR-BO-10002545  Furniture    Bookcases
# 52        28314    South  FUR-BO-10002213  Furniture    Bookcases
# 78        98103     West  FUR-BO-10000468  Furniture    Bookcases
# 104       30080    South  FUR-BO-10004015  Furniture    Bookcases
# 224       11561     East  FUR-BO-10003272  Furniture    Bookcases
# 265       78550  Central  FUR-BO-10004409  Furniture    Bookcases
# 287       80122     West  FUR-BO-10002202  Furniture    Bookcases
# 307       44105     East  FUR-BO-10004357  Furniture    Bookcases
# 329       45503     East  FUR-BO-10004015  Furniture    Bookcases
#
#                                           Product Name     Sales  Quantity  \
# 0    Bush Westfield Collection Bookcases, Medium Ch...   173.940         3
# 17   Atlantic Metals Mobile 3-Shelf Bookcases, Cust...  1565.880         6
# 52    Sauder Forest Hills Library, Woodland Oak Finish   451.136         4
# 78             O'Sullivan 2-Shelf Heavy-Duty Bookcases    48.580         1
# 104   Bush Andora Bookcase, Maple/Graphite Gray Finish   239.980         2
# 224     O'Sullivan Living Dimensions 5-Shelf Bookcases   176.784         1
# 265  Safco Value Mate Series Steel Bookcases, Baked...   241.332         5
# 287  Atlantic Metals Mobile 2-Shelf Bookcases, Cust...    72.294         1
# 307     O'Sullivan Living Dimensions 3-Shelf Bookcases   301.470         3
# 329   Bush Andora Bookcase, Maple/Graphite Gray Finish   299.975         5
#
#      Discount    Profit
# 0        0.00   38.2668
# 17       0.00  407.1288
# 52       0.20  -67.6704
# 78       0.00    7.7728
# 104      0.00   52.7956
# 224      0.20  -22.0980
# 265      0.32  -14.1960
# 287      0.70  -98.8018
# 307      0.50 -241.1760
# 329      0.50 -167.9860
#
# [10 rows x 21 columns]

# %%
#Negative profit table products
TableProdProfSales = JustTables[['Product Name', 'Profit','Sales']].groupby('Product Name').sum().sort_values('Profit')
display(TableProdProfSales)
# Out:
#                                                        Profit       Sales
# Product Name
# Chromcraft Bull-Nose Wood Oval Conference Table... -2876.1156   9917.6400
# Bush Advantage Collection Racetrack Conference ... -1934.3976   9544.7250
# Balt Solid Wood Round Tables                       -1201.0581   6518.7540
# BoxOffice By Design Rectangular and Half-Moon M... -1148.4375   1706.2500
# Riverside Furniture Oval Coffee Table, Oval End... -1147.4000   4446.1750
# Bretford “Just In Time” Height-Adjustable Multi...  -964.1940   5634.9000
# Bevis Oval Conference Table, Walnut                 -856.0144   6942.0680
# BPI Conference Tables                               -795.9725   2241.8675
# Hon 94000 Series Round Tables                       -681.2140   7404.5000
# Chromcraft Bull-Nose Wood 48" x 96" Rectangular...  -611.5878   4297.6440
# Hon Racetrack Conference Tables                     -598.5228   3963.9010
# Bevis Rectangular Conference Tables                 -586.8396   1007.2620
# Bretford CR4500 Series Slim Rectangular Table       -532.7613   7242.7680
# Bevis Round Conference Table Top, X-Base            -519.9410   2671.4210
# KI Conference Tables                                -479.2164   2140.8780
# Bevis Traditional Conference Table Top, Plinth ...  -456.7032   2033.4960
# Chromcraft Rectangular Conference Tables            -450.2430   4952.6730
# Bevis Boat-Shaped Conference Table                  -445.5870   2542.4670
# Riverside Furniture Stanwyck Manor Table Series     -415.9325    917.9200
# Chromcraft 48" x 96" Racetrack Double Pedestal ...  -404.0064   5098.1760
# Hon 2111 Invitation Series Corner Table             -401.9904   3140.5500
# Iceberg OfficeWorks 42" Round Tables                -392.5480   3457.4420
# Balt Split Level Computer Training Table            -357.9750   1040.6250
# Lesro Round Back Collection Coffee Table, End T...  -328.5900   2847.7800
# Bretford Rectangular Conference Table Tops          -327.2331  12995.2915
# Hon Rectangular Conference Tables                   -295.8150   3481.5150
# KI Adjustable-Height Table                          -248.4822   4552.6410
# Hon 5100 Series Wood Tables                         -238.6036   5965.0900
# Balt Solid Wood Rectangular Table                   -216.2545    828.0965
# Laminate Occasional Tables                          -206.5342   2096.1680
# Bevis Round Bullnose 29" High Table Top             -192.1854   4544.9250
# Chromcraft Round Conference Tables                  -189.9761   8209.0590
# Hon 30" x 60" Table with Locking Drawer             -177.3512   1296.0280
# Bevis 44 x 96 Conference Tables                     -164.7200   3253.2200
# Hon 61000 Series Interactive Training Tables        -148.3962    653.1210
# Bush Andora Conference Table, Maple/Graphite Gr...  -143.6232   1436.2320
# Hon 2111 Invitation Series Straight Table           -115.3074   2040.0540
# Barricks 18" x 48" Non-Folding Utility Table wi...  -104.8320   1088.6400
# Office Impressions End Table, 20-1/2"H x 24"W x...   -66.8272   5801.8160
# Bevis Round Conference Room Tables and Bases         -39.4438    519.9410
# Anderson Hickey Conga Table Tops & Accessories       -17.5145     51.7820
# Lesro Sheffield Collection Coffee Table, End Ta...   -12.1329   2298.1140
# Barricks Non-Folding Utility Table with Steel L...    15.3522    136.4640
# Safco Drafting Table                                  34.0704    638.8200
# SAFCO PlanMaster Boards, 60w x 37-1/2d, White M...    54.7164   2979.0040
# Hon 4060 Series Tables                                96.2856   1231.5600
# Chromcraft Bull-Nose Wood Round Conference Tabl...   100.2110   3354.8900
# Bevis Round Conference Table Top & Single Colum...   100.9746   2297.5380
# Bush Advantage Collection Round Conference Table     210.4740   3401.6000
# Bush Cubix Conference Tables, Fully Assembled        311.8230   3603.2880
# Global Adaptabilities Conference Tables              354.0348   3540.3480
# Hon Practical Foundations 30 x 60 Training Tabl...   430.0695   4334.8275
# Bevis 36 x 72 Conference Tables                      448.1640   4332.2520
# Bretford CR8500 Series Meeting Room Furniture        461.1270   6776.5620
# Hon Non-Folding Utility Tables                       541.6540   3775.6470
# SAFCO PlanMaster Heigh-Adjustable Drafting Tabl...   608.0430   3739.1150

# %%
#multi-criteria .loc functions
SubCatSalesProf = SalesData[['Segment','Sub-Category','Sales','Profit',]]
CorpTableSalesProf = SubCatSalesProf.loc[(SubCatSalesProf ['Segment']== 'Corporate') & (SubCatSalesProf["Sub-Category"]== 'Tables')]
TotalCorpTablesSalesProf = CorpTableSalesProf.groupby(by = ['Segment', 'Sub-Category']).sum().round()
display(TotalCorpTablesSalesProf)
# Out:
#                           Sales  Profit
# Segment   Sub-Category
# Corporate Tables        70872.0 -4906.0

# %%
#Negative Tables Only
JustTables = SalesData.loc[SalesData['Sub-Category']== "Tables"]
TableProf = JustTables[['Product Name', 'Profit']].groupby('Product Name').sum()
NegTables = TableProf[TableProf["Profit"] < 0.0]
display(NegTables)
# Out:
#                                                        Profit
# Product Name
# Anderson Hickey Conga Table Tops & Accessories       -17.5145
# BPI Conference Tables                               -795.9725
# Balt Solid Wood Rectangular Table                   -216.2545
# Balt Solid Wood Round Tables                       -1201.0581
# Balt Split Level Computer Training Table            -357.9750
# Barricks 18" x 48" Non-Folding Utility Table wi...  -104.8320
# Bevis 44 x 96 Conference Tables                     -164.7200
# Bevis Boat-Shaped Conference Table                  -445.5870
# Bevis Oval Conference Table, Walnut                 -856.0144
# Bevis Rectangular Conference Tables                 -586.8396
# Bevis Round Bullnose 29" High Table Top             -192.1854
# Bevis Round Conference Room Tables and Bases         -39.4438
# Bevis Round Conference Table Top, X-Base            -519.9410
# Bevis Traditional Conference Table Top, Plinth ...  -456.7032
# BoxOffice By Design Rectangular and Half-Moon M... -1148.4375
# Bretford CR4500 Series Slim Rectangular Table       -532.7613
# Bretford Rectangular Conference Table Tops          -327.2331
# Bretford “Just In Time” Height-Adjustable Multi...  -964.1940
# Bush Advantage Collection Racetrack Conference ... -1934.3976
# Bush Andora Conference Table, Maple/Graphite Gr...  -143.6232
# Chromcraft 48" x 96" Racetrack Double Pedestal ...  -404.0064
# Chromcraft Bull-Nose Wood 48" x 96" Rectangular...  -611.5878
# Chromcraft Bull-Nose Wood Oval Conference Table... -2876.1156
# Chromcraft Rectangular Conference Tables            -450.2430
# Chromcraft Round Conference Tables                  -189.9761
# Hon 2111 Invitation Series Corner Table             -401.9904
# Hon 2111 Invitation Series Straight Table           -115.3074
# Hon 30" x 60" Table with Locking Drawer             -177.3512
# Hon 5100 Series Wood Tables                         -238.6036
# Hon 61000 Series Interactive Training Tables        -148.3962
# Hon 94000 Series Round Tables                       -681.2140
# Hon Racetrack Conference Tables                     -598.5228
# Hon Rectangular Conference Tables                   -295.8150
# Iceberg OfficeWorks 42" Round Tables                -392.5480
# KI Adjustable-Height Table                          -248.4822
# KI Conference Tables                                -479.2164
# Laminate Occasional Tables                          -206.5342
# Lesro Round Back Collection Coffee Table, End T...  -328.5900
# Lesro Sheffield Collection Coffee Table, End Ta...   -12.1329
# Office Impressions End Table, 20-1/2"H x 24"W x...   -66.8272
# Riverside Furniture Oval Coffee Table, Oval End... -1147.4000
# Riverside Furniture Stanwyck Manor Table Series     -415.9325

# %% [markdown]
# ICW #1: Grouping and .Loc Function

# %%
#1 
CatOS_table = SalesData[["Category", "Sub-Category", "Sales", "Profit"]]
table2 = CatOS_table.loc[(CatOS_table["Category"] == "Office Supplies")]
output = table2.groupby(by = ["Sub-Category"]).sum()
print(output)
# Out:
#                    Sales      Profit
# Sub-Category
# Appliances    107532.161  18138.0054
# Art            27118.792   6527.7870
# Binders       203412.733  30221.7633
# Envelopes      16476.402   6964.1767
# Fasteners       3024.280    949.5182
# Labels         12486.312   5546.2540
# Paper          78479.206  34053.5693
# Storage       223843.608  21278.8264
# Supplies       46673.538  -1189.0995

# %%
#2
table = SalesData[["Category", "Sub-Category", "Sales", "Profit", "Product Name"]]
new_table = table.loc[(table["Category"] == "Office Supplies")]
total = new_table.groupby(by = ["Product Name"]).sum()
output = total.sort_values(by = "Profit", ascending = "False")
print(output)
# Out:
#                                                         Sales     Profit
# Product Name
# GBC DocuBind P400 Electric Binding System           17965.068 -1878.1662
# Martin Yale Chadless Opener Electric Letter Opener  16656.200 -1299.1836
# 3.6 Cubic Foot Counter Height Office Refrigerator    2946.200  -872.0752
# Tennsco Single-Tier Lockers                          9158.296  -825.7480
# SAFCO Commercial Wire Shelving, Black                4199.456  -635.4440
# ...                                                       ...        ...
# Ibico Ibimaster 300 Manual Binding System            7985.383  2318.3370
# Fellowes PB300 Plastic Comb Binding Machine          8070.192  2518.0551
# Honeywell Enviracaire Portable HEPA Air Cleaner...  11304.440  3247.0200
# Ibico EPK-21 Electric Binding System                15875.916  3345.2823
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384  7753.0390
#
# [1058 rows x 2 columns]

# %%
#3
display(output[output["Profit"] > 0])
# Out:
#                                                         Sales        Profit
# Product Name
# Avery Trapezoid Extra Heavy Duty 4" Binders           314.550  2.131628e-14
# Bagged Rubber Bands                                    25.704  3.024000e-01
# Letter Slitter                                         10.080  3.024000e-01
# Hoover Replacement Belt for Commercial Guardsma...      9.768  4.440000e-01
# Alliance Rubber Bands                                  13.440  5.376000e-01
# ...                                                       ...           ...
# Ibico Ibimaster 300 Manual Binding System            7985.383  2.318337e+03
# Fellowes PB300 Plastic Comb Binding Machine          8070.192  2.518055e+03
# Honeywell Enviracaire Portable HEPA Air Cleaner...  11304.440  3.247020e+03
# Ibico EPK-21 Electric Binding System                15875.916  3.345282e+03
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384  7.753039e+03
#
# [934 rows x 2 columns]

# %% [markdown]
# Beginning next module

# %%
#establish dataframe 
JustTables = SalesData.loc[SalesData['Sub-Category']=='Tables']

# %%
#Table profits and sales by customer segment and region
TableSegment = JustTables[['Segment', 'Profit', 'Sales']]
SegTotalProfSales = TableSegment.groupby('Segment').sum().sort_values('Profit')
print(SegTotalProfSales)
# Out:
#                 Profit       Sales
# Segment
# Consumer    -9728.0378  99933.7950
# Corporate   -4906.4986  70871.7175
# Home Office -3090.9447  36160.0195

# %%
#By Region
TableRegion = JustTables[['Region', 'Profit', 'Sales']]
RegionTotalProfSales = TableRegion.groupby('Region').sum().sort_values('Profit')
print(RegionTotalProfSales)
# Out:
#              Profit      Sales
# Region
# East    -11025.3801  39139.807
# South    -4623.0579  43916.192
# Central  -3559.6504  39154.971
# West      1482.6073  84754.562

# %%
#Total Table profits and sales for each segment in 'West' region
TableSegRegion = JustTables[['Segment', 'Region', 'Profit', 'Sales']]
WestTableSegment = TableSegRegion.loc[TableSegRegion['Region']=='West']
WestProfSales = WestTableSegment.groupby('Segment').sum().sort_values('Profit')
print(WestProfSales)
# Out:
#                 Profit      Sales
# Segment
# Home Office  -113.5648  16009.185
# Consumer      521.9717  40607.486
# Corporate    1074.2004  28137.891

# %%
#Calculate to see average mean discount on tables
#.mean to see average discounts on tables
JustTablesDiscount = JustTables[['Product Name','Discount','Profit']]
AveDiscount = JustTables = JustTablesDiscount.mean() #step for determining overall average discount and profit
print(AveDiscount)
#discounts for ech table product, most discounted at top of list using .sort_values
JustTablesAveDiscount = JustTablesDiscount.groupby('Product Name').mean().sort_values('Discount',ascending = False)
print(JustTablesAveDiscount.head(25))
# Out:
# Discount     0.261285
# Profit     -55.565771
# dtype: float64
#                                                     Discount      Profit
# Product Name
# BoxOffice By Design Rectangular and Half-Moon M...  0.483333 -382.812500
# Bevis Rectangular Conference Tables                 0.475000 -146.709900
# Balt Split Level Computer Training Table            0.380000  -71.595000
# BPI Conference Tables                               0.370000 -159.194500
# Riverside Furniture Stanwyck Manor Table Series     0.366667 -138.644167
# Bush Advantage Collection Racetrack Conference ...  0.350000 -276.342514
# Bevis Traditional Conference Table Top, Plinth ...  0.333333 -152.234400
# Hon 30" x 60" Table with Locking Drawer             0.333333  -59.117067
# Chromcraft Bull-Nose Wood 48" x 96" Rectangular...  0.333333 -101.931300
# Hon Rectangular Conference Tables                   0.325000  -73.953750
# KI Conference Tables                                0.325000  -59.902050
# Chromcraft Rectangular Conference Tables            0.322222  -50.027000
# Barricks 18" x 48" Non-Folding Utility Table wi...  0.320000  -20.966400
# Bevis Boat-Shaped Conference Table                  0.316667  -74.264500
# Chromcraft 48" x 96" Racetrack Double Pedestal ...  0.316667  -67.334400
# Hon 61000 Series Interactive Training Tables        0.311111  -16.488467
# Anderson Hickey Conga Table Tops & Accessories      0.300000   -8.757250
# Bush Andora Conference Table, Maple/Graphite Gr...  0.300000  -35.905800
# Riverside Furniture Oval Coffee Table, Oval End...  0.300000 -229.480000
# Lesro Round Back Collection Coffee Table, End T...  0.287500  -41.073750
# Hon Racetrack Conference Tables                     0.283333  -99.753800
# Chromcraft Bull-Nose Wood Oval Conference Table...  0.280000 -575.223120
# SAFCO PlanMaster Heigh-Adjustable Drafting Tabl...  0.280000  121.608600
# Bevis Oval Conference Table, Walnut                 0.275000 -107.001800
# Hon 2111 Invitation Series Straight Table           0.271429  -16.472486
# /var/folders/j8/qppqqwyn6md61c5w9dqy177m0000gn/T/ipykernel_13013/416835056.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   AveDiscount = JustTables = JustTablesDiscount.mean() #step for determining overall average discount and profit

# %%
#Correlation between table discounts, sales, and dates (.dt) 
JustTables = SalesData.loc[SalesData['Sub-Category']=='Tables']

import scipy.stats
x = "Discount"
y = "Sales"
GetCorrelation = scipy.stats.spearmanr(JustTables[x], JustTables[y])

Corr = GetCorrelation[0]
CorrRounded = str(Corr.round(2))

pValue = GetCorrelation[1]
pValuerounded = str(pValue.round(5))

print('The correlation between' + x + 'and' + y + 'is:' + CorrRounded)
print('At p value:' + pValuerounded)
# Out:
# The correlation betweenDiscountandSalesis:-0.29
# At p value:0.0

# %%
#New series (column) to hold year portion of order date
#Copy to preserve previous dataframe
JustTablesYears = JustTables.copy()
#Create new column called year, fill it with year portion of each row's order date
JustTablesYears['Year'] = JustTablesYears['Order Date'].dt.year
#check to make sure new year column is present (at the end)
print(JustTablesYears.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Year'],
#       dtype='object')

# %%
#Grouping and summing annual sales
#year is now isolated, we group by year and total up profit, sales
YearlyProfSales = JustTablesYears[['Year', 'Profit', 'Sales']].groupby('Year').sum()
print('The yearly profit and sales for tables are:')
print(YearlyProfSales)
# Out:
# The yearly profit and sales for tables are:
#          Profit       Sales
# Year
# 2017 -2950.9418  60833.2005
# 2018 -8140.6947  60893.5425
# 2019 -3124.0427  46088.3655
# 2020 -3509.8019  39150.4235

# %% [markdown]
# Region, Segment, and Temporal Effects

# %%
#1
JustCopiers = SalesData.loc[SalesData['Sub-Category']=='Copiers']

# %%
#2
TableSegRegion = JustCopiers[['Segment', 'Region', 'Profit', 'Sales']]
EastTableSeg = TableSegRegion.loc[TableSegRegion['Region']=='East']
EastProfSales = EastTableSeg.groupby('Segment').sum().sort_values('Profit')
print(EastProfSales)
# Out:
#                 Profit      Sales
# Segment
# Corporate    1134.9765   4219.914
# Home Office  7229.9328  18599.842
# Consumer     8657.9325  30399.706

# %%
#3
TableSeg = JustCopiers[['Segment', 'Profit', 'Sales']]
SegTotalProfSales = TableSeg.groupby('Segment').sum().sort_values('Profit')
print(SegTotalProfSales)
# Out:
#                  Profit      Sales
# Segment
# Home Office  12543.8354  32879.574
# Corporate    18990.2789  46829.386
# Consumer     24083.7106  69819.070

# %%
#4
JustCopiers = SalesData.loc[SalesData['Sub-Category']=='Copiers']

JustCopiersMonths = JustCopiers.copy()
JustCopiersMonths['Month'] = JustCopiersMonths['Order Date'].dt.month

JustCopiers = JustCopiersMonths[['Month','Sales','Profit']]
AverageProfit = JustCopiers.mean()
print(AverageProfit)
JustCopiersAverageProfit = JustCopiers.groupby('Month').mean()
print(JustCopiersAverageProfit.head(25))
# Out:
# Month        7.852941
# Sales     2198.941618
# Profit     817.909190
# dtype: float64
#              Sales       Profit
# Month
# 1      1979.959000   749.986500
# 3      3198.717000  1380.549925
# 4       969.973000   321.740975
# 5      2628.541429   531.421286
# 6       899.970000   314.989500
# 7      1397.113143   394.563614
# 8      1145.980000   400.992960
# 9      1146.638000   427.211233
# 10     6169.959333  2643.983000
# 11     2164.269143   897.280486
# 12     1566.637500   582.906458

# %%
#5
JustCopiers = SalesData.loc[SalesData['Sub-Category']=='Copiers']
JustCopiers = JustCopiers[['Product Name','Sales','Profit']]
AverageProfit = JustCopiers.mean()
print(AverageProfit)
JustCopiersAverageProfit = JustCopiers.groupby('Product Name').mean().sort_values('Sales',ascending = False)
print(JustCopiersAverageProfit.head(25))
# Out:
# Sales     2198.941618
# Profit     817.909190
# dtype: float64
#                                                            Sales       Profit
# Product Name
# Canon imageCLASS 2200 Advanced Copier               12319.964800  5039.985600
# Canon PC1060 Personal Laser Copier                   2904.958500  1142.733675
# Hewlett Packard LaserJet 3310 Copier                 2354.960750   872.985450
# Canon Image Class D660 Copier                        1979.967000   845.985900
# Canon PC940 Copier                                   1889.958000   697.484500
# Canon Imageclass D680 Copier / Fax                   1791.974400   559.992000
# Sharp AL-1530CS Digital Copier                       1599.968000   516.239675
# Canon PC1080F Personal Copier                        1499.975000   493.491775
# Hewlett Packard 610 Color Digital Copier / Printer   1271.403143   446.419643
# Hewlett Packard 310 Color Digital Copier              699.976667   139.995333
# Brother DCP1000 Digital 3 in 1 Multifunction Ma...    694.262571   164.994500
# Canon PC-428 Personal Copier                          686.632333   244.987750
# Sharp 1540cs Digital Laser Copier                     628.560000   235.710000
# /var/folders/j8/qppqqwyn6md61c5w9dqy177m0000gn/T/ipykernel_13013/2978257265.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   AverageProfit = JustCopiers.mean()

# %% [markdown]
# Combining Several Levels of Analysis at Once

# %%
#Average Table Discounts by Region
JustTables = SalesData.loc[SalesData["Sub-Category"]=="Tables"]
RegJustTableDiscount = JustTables[["Region", "Discount",]].groupby('Region').mean()
print(RegJustTableDiscount)
# Out:
#          Discount
# Region
# Central  0.262500
# East     0.373750
# South    0.222549
# West     0.200000

# %%
#Code to look at table regional discounts by year
#Create dataframe reference to only those rows where sub-cat value is tables
JustTables = SalesData.loc[SalesData["Sub-Category"]=="Tables"]
JustTablesYear = JustTables.copy() #make copy of JustTable
JustTablesYear['Year'] = JustTablesYear["Order Date"].dt.year
#Just checking column with a print
#print(JustTablesYear.columns)
Years = JustTablesYear.Year.unique()
#can check array of years with print too
#print(Years)
#just keep what we need
RegJustTableYear = JustTablesYear[["Region", "Year", "Discount"]] 
#loop through array of years
for year in Years:
  OneYear = RegJustTableYear.loc[RegJustTableYear['Year'] == year] #locate one year's data one at a time
  NoYear = OneYear[['Region', 'Discount']] #gettubg rid of year columnm not needed after .loc and .mean will try to average
  YearlyRegDiscount = NoYear.groupby('Region').mean() #group by region, sum up sales and profits
  print('\nRegional table discounts for the year: ' + str(year)) #title
  #results
  print(YearlyRegDiscount)
  print("*"*40)
# Out:
# Regional table discounts for the year: 2017
#          Discount
# Region
# Central  0.205882
# East     0.368182
# South    0.250000
# West     0.240625
# ****************************************
#
# Regional table discounts for the year: 2018
#          Discount
# Region
# Central  0.292308
# East     0.373913
# South    0.270588
# West     0.178947
# ****************************************
#
# Regional table discounts for the year: 2019
#          Discount
# Region
# Central  0.326667
# East     0.380000
# South    0.113636
# West     0.208000
# ****************************************
#
# Regional table discounts for the year: 2020
#          Discount
# Region
# Central  0.207143
# East     0.373333
# South    0.218750
# West     0.166667
# ****************************************

# %%
#Segment Table Profits and Sales by Region
#create a numpy array of UNIQUE regions
Regions = JustTables.Region.unique()
TableSegRegion = JustTables[['Segment', 'Region', 'Profit', 'Sales']]
#loop through regions array
for region in Regions:
  #with each loop, variable region takes on different region value
  #.loc function finds rows with specific region, ignoring remainder of loop.
  TableSegment = TableSegRegion.loc[TableSegRegion['Region']==region]
  TableSegmentProfSales = TableSegment.groupby('Segment').sum().sort_values('Profit')
  #next print() line is to improve legibility
  print('\nThe table sub-category profits and sales for each customer segment in the ' + region + 'are as follows:')
  #data output, different with each loop
  print(TableSegmentProfSales)
  #visual formatting 
  print('-'*40)
# Out:
# The table sub-category profits and sales for each customer segment in the Centralare as follows:
#                 Profit      Sales
# Segment
# Consumer    -3964.1571  20835.000
# Home Office  -302.6739   5757.378
# Corporate     707.1806  12562.593
# ----------------------------------------
#
# The table sub-category profits and sales for each customer segment in the Eastare as follows:
#                 Profit      Sales
# Segment
# Corporate   -5299.6557  17551.558
# Consumer    -3708.3528  14082.467
# Home Office -2017.3716   7505.782
# ----------------------------------------
#
# The table sub-category profits and sales for each customer segment in the Westare as follows:
#                 Profit      Sales
# Segment
# Home Office  -113.5648  16009.185
# Consumer      521.9717  40607.486
# Corporate    1074.2004  28137.891
# ----------------------------------------
#
# The table sub-category profits and sales for each customer segment in the Southare as follows:
#                 Profit       Sales
# Segment
# Consumer    -2577.4996  24408.8420
# Corporate   -1388.2239  12619.6755
# Home Office  -657.3344   6887.6745
# ----------------------------------------

# %%
#Average annual table discounts for each segment by region code
#Code to look at Table customer segment discounts by year and region
JustTables = SalesData.loc[SalesData["Sub-Category"]=="Tables"]
JustTablesYear = JustTables.copy() #make copy of JustTable
JustTablesYear['Year'] = JustTablesYear["Order Date"].dt.year 
Years = JustTablesYear.Year.unique() 
Regions = JustTablesYear.Region.unique()
SegJustTableYear = JustTablesYear [['Segment', 'Year', 'Discount', 'Region']]
#looping through year array
for year in Years:
  OneYear = SegJustTableYear.loc[SegJustTableYear["Year"]==year]
  NoYear = OneYear[['Segment','Discount','Region']]
  #looping through region array
  for region in Regions:
    OneRegion = NoYear.loc[NoYear['Region']==region]
    YearlySegRegDiscount = OneRegion.groupby('Segment').mean()
    print('\n' + str(year) + ' Table discounts by customer segment in the ' + region + ' region')
    print(YearlySegRegDiscount)
    print('-'*40)
# Out:
# 2017 Table discounts by customer segment in the Central region
#              Discount
# Segment
# Consumer         0.32
# Corporate        0.06
# Home Office      0.00
# ----------------------------------------
#
# 2017 Table discounts by customer segment in the East region
#              Discount
# Segment
# Consumer     0.336364
# Corporate    0.400000
# Home Office  0.400000
# ----------------------------------------
#
# 2017 Table discounts by customer segment in the West region
#              Discount
# Segment
# Consumer     0.208333
# Corporate    0.220000
# Home Office  0.380000
# ----------------------------------------
#
# 2017 Table discounts by customer segment in the South region
#            Discount
# Segment
# Consumer   0.183333
# Corporate  0.350000
# ----------------------------------------
#
# 2018 Table discounts by customer segment in the Central region
#              Discount
# Segment
# Consumer     0.293333
# Corporate    0.320000
# Home Office  0.266667
# ----------------------------------------
#
# 2018 Table discounts by customer segment in the East region
#              Discount
# Segment
# Consumer     0.371429
# Corporate    0.362500
# Home Office  0.387500
# ----------------------------------------
#
# 2018 Table discounts by customer segment in the West region
#              Discount
# Segment
# Consumer     0.188235
# Corporate    0.192308
# Home Office  0.137500
# ----------------------------------------
#
# 2018 Table discounts by customer segment in the South region
#              Discount
# Segment
# Consumer     0.208333
# Corporate    0.330000
# Home Office  0.283333
# ----------------------------------------
#
# 2019 Table discounts by customer segment in the Central region
#              Discount
# Segment
# Consumer     0.363636
# Corporate    0.300000
# Home Office  0.150000
# ----------------------------------------
#
# 2019 Table discounts by customer segment in the East region
#              Discount
# Segment
# Consumer       0.3625
# Corporate      0.3900
# Home Office    0.4000
# ----------------------------------------
#
# 2019 Table discounts by customer segment in the West region
#              Discount
# Segment
# Consumer     0.238462
# Corporate    0.190000
# Home Office  0.100000
# ----------------------------------------
#
# 2019 Table discounts by customer segment in the South region
#              Discount
# Segment
# Consumer         0.17
# Corporate        0.10
# Home Office      0.00
# ----------------------------------------
#
# 2020 Table discounts by customer segment in the Central region
#              Discount
# Segment
# Consumer         0.25
# Corporate        0.15
# Home Office      0.20
# ----------------------------------------
#
# 2020 Table discounts by customer segment in the East region
#              Discount
# Segment
# Consumer     0.400000
# Corporate    0.360000
# Home Office  0.333333
# ----------------------------------------
#
# 2020 Table discounts by customer segment in the West region
#              Discount
# Segment
# Consumer     0.193333
# Corporate    0.100000
# Home Office  0.100000
# ----------------------------------------
#
# 2020 Table discounts by customer segment in the South region
#            Discount
# Segment
# Consumer       0.25
# Corporate      0.00
# ----------------------------------------

# %%
#.agg to combine sum and mean
TablesProduct = JustTables[['Product Name', 'Profit', 'Discount']]
TablesTotalProfAveDiscount = TablesProduct.groupby('Product Name').agg({'Profit':'sum', 'Discount':"mean"})
display(TablesTotalProfAveDiscount)
# Out:
#                                                        Profit  Discount
# Product Name
# Anderson Hickey Conga Table Tops & Accessories       -17.5145  0.300000
# BPI Conference Tables                               -795.9725  0.370000
# Balt Solid Wood Rectangular Table                   -216.2545  0.262500
# Balt Solid Wood Round Tables                       -1201.0581  0.200000
# Balt Split Level Computer Training Table            -357.9750  0.380000
# Barricks 18" x 48" Non-Folding Utility Table wi...  -104.8320  0.320000
# Barricks Non-Folding Utility Table with Steel L...    15.3522  0.200000
# Bevis 36 x 72 Conference Tables                      448.1640  0.162500
# Bevis 44 x 96 Conference Tables                     -164.7200  0.180000
# Bevis Boat-Shaped Conference Table                  -445.5870  0.316667
# Bevis Oval Conference Table, Walnut                 -856.0144  0.275000
# Bevis Rectangular Conference Tables                 -586.8396  0.475000
# Bevis Round Bullnose 29" High Table Top             -192.1854  0.260000
# Bevis Round Conference Room Tables and Bases         -39.4438  0.250000
# Bevis Round Conference Table Top & Single Colum...   100.9746  0.220000
# Bevis Round Conference Table Top, X-Base            -519.9410  0.266667
# Bevis Traditional Conference Table Top, Plinth ...  -456.7032  0.333333
# BoxOffice By Design Rectangular and Half-Moon M... -1148.4375  0.483333
# Bretford CR4500 Series Slim Rectangular Table       -532.7613  0.262500
# Bretford CR8500 Series Meeting Room Furniture        461.1270  0.183333
# Bretford Rectangular Conference Table Tops          -327.2331  0.245833
# Bretford “Just In Time” Height-Adjustable Multi...  -964.1940  0.225000
# Bush Advantage Collection Racetrack Conference ... -1934.3976  0.350000
# Bush Advantage Collection Round Conference Table     210.4740  0.237500
# Bush Andora Conference Table, Maple/Graphite Gr...  -143.6232  0.300000
# Bush Cubix Conference Tables, Fully Assembled        311.8230  0.200000
# Chromcraft 48" x 96" Racetrack Double Pedestal ...  -404.0064  0.316667
# Chromcraft Bull-Nose Wood 48" x 96" Rectangular...  -611.5878  0.333333
# Chromcraft Bull-Nose Wood Oval Conference Table... -2876.1156  0.280000
# Chromcraft Bull-Nose Wood Round Conference Tabl...   100.2110  0.183333
# Chromcraft Rectangular Conference Tables            -450.2430  0.322222
# Chromcraft Round Conference Tables                  -189.9761  0.257692
# Global Adaptabilities Conference Tables              354.0348  0.150000
# Hon 2111 Invitation Series Corner Table             -401.9904  0.200000
# Hon 2111 Invitation Series Straight Table           -115.3074  0.271429
# Hon 30" x 60" Table with Locking Drawer             -177.3512  0.333333
# Hon 4060 Series Tables                                96.2856  0.200000
# Hon 5100 Series Wood Tables                         -238.6036  0.214286
# Hon 61000 Series Interactive Training Tables        -148.3962  0.311111
# Hon 94000 Series Round Tables                       -681.2140  0.160000
# Hon Non-Folding Utility Tables                       541.6540  0.200000
# Hon Practical Foundations 30 x 60 Training Tabl...   430.0695  0.175000
# Hon Racetrack Conference Tables                     -598.5228  0.283333
# Hon Rectangular Conference Tables                   -295.8150  0.325000
# Iceberg OfficeWorks 42" Round Tables                -392.5480  0.200000
# KI Adjustable-Height Table                          -248.4822  0.236111
# KI Conference Tables                                -479.2164  0.325000
# Laminate Occasional Tables                          -206.5342  0.233333
# Lesro Round Back Collection Coffee Table, End T...  -328.5900  0.287500
# Lesro Sheffield Collection Coffee Table, End Ta...   -12.1329  0.177778
# Office Impressions End Table, 20-1/2"H x 24"W x...   -66.8272  0.180000
# Riverside Furniture Oval Coffee Table, Oval End... -1147.4000  0.300000
# Riverside Furniture Stanwyck Manor Table Series     -415.9325  0.366667
# SAFCO PlanMaster Boards, 60w x 37-1/2d, White M...    54.7164  0.260000
# SAFCO PlanMaster Heigh-Adjustable Drafting Tabl...   608.0430  0.280000
# Safco Drafting Table                                  34.0704  0.200000

# %% [markdown]
# 1. Focus on the Bookcases sub-category. Loop through the years and for each year, show total
# profit and sales and average discount for region.
# 2. Show a bar chat of tables by region

# %%
BookcasesProduct = JustBookcases[['Product Name', 'Profit', 'Discount']]
BookcasesTotalProfAveDiscount = BookcasesProduct.groupby('Product Name').agg({'Profit':'sum', 'Discount':"mean"})
print(BookcasesTotalProfAveDiscount)
# Out:
#                                                       Profit  Discount
# Product Name
# Atlantic Metals Mobile 2-Shelf Bookcases, Custo... -113.2606  0.510000
# Atlantic Metals Mobile 3-Shelf Bookcases, Custo...  780.3302  0.183750
# Atlantic Metals Mobile 4-Shelf Bookcases, Custo... -126.4410  0.266667
# Atlantic Metals Mobile 5-Shelf Bookcases, Custo...   15.0490  0.316250
# Bestar Classic Bookcase                            -612.9387  0.315000
# Bush Andora Bookcase, Maple/Graphite Gray Finish    135.5887  0.166667
# Bush Birmingham Collection Bookcase, Dark Cherry   -117.8820  0.300000
# Bush Cubix Collection Bookcases, Fully Assembled     48.6156  0.233333
# Bush Heritage Pine Collection 5-Shelf Bookcase,... -208.6504  0.233750
# Bush Mission Pointe Library                          24.1568  0.173333
# Bush Saratoga Collection 5-Shelf Bookcase, Hano...  -12.6882  0.150000
# Bush Somerset Collection Bookcase                   -56.3214  0.212500
# Bush Westfield Collection Bookcases, Dark Cherr...  -97.4064  0.233333
# Bush Westfield Collection Bookcases, Dark Cherr... -190.8522  0.700000
# Bush Westfield Collection Bookcases, Fully Asse...   73.7154  0.195000
# Bush Westfield Collection Bookcases, Medium Che...  -20.2930  0.230000
# DMI Eclipse Executive Suite Bookcases                90.1764  0.183333
# Global Adaptabilites Bookcase, Cherry/Storm Gra...  206.8704  0.000000
# Hon 4-Shelf Metal Bookcases                        -191.8620  0.250000
# Hon Metal Bookcases, Black                          -26.9724  0.244000
# Hon Metal Bookcases, Gray                           229.9752  0.000000
# Hon Metal Bookcases, Putty                          362.7078  0.040000
# O'Sullivan 2-Door Barrister Bookcase in Odessa ...  566.4674  0.150000
# O'Sullivan 2-Shelf Heavy-Duty Bookcases            -133.1092  0.183333
# O'Sullivan 3-Shelf Heavy-Duty Bookcases             147.0942  0.170000
# O'Sullivan 4-Shelf Bookcase in Odessa Pine         -975.0988  0.421429
# O'Sullivan 5-Shelf Heavy-Duty Bookcases             -12.2910  0.175000
# O'Sullivan Cherrywood Estates Traditional Barri...  -78.3636  0.150000
# O'Sullivan Cherrywood Estates Traditional Bookcase   27.1936  0.100000
# O'Sullivan Elevations Bookcase, Cherry Finish       -68.1096  0.200000
# O'Sullivan Living Dimensions 2-Shelf Bookcases      -78.6370  0.110000
# O'Sullivan Living Dimensions 3-Shelf Bookcases     -170.8330  0.200000
# O'Sullivan Living Dimensions 5-Shelf Bookcases     -755.7516  0.240000
# O'Sullivan Manor Hill 2-Door Library in Brianna... -285.9484  0.247500
# O'Sullivan Plantations 2-Door Library in Landve... -767.7436  0.332000
# Riverside Palais Royal Lawyers Bookcase, Royale... -669.5448  0.234000
# Rush Hierlooms Collection 1" Thick Stackable Bo...  410.3520  0.037500
# Rush Hierlooms Collection Rich Wood Bookcases       -70.8312  0.160000
# Safco Value Mate Series Steel Bookcases, Baked ...   -9.9372  0.245000
# Safco Value Mate Steel Bookcase, Baked Enamel F...  106.4700  0.200000
# Sauder Barrister Bookcases                         -294.7672  0.406667
# Sauder Camden County Barrister Bookcase, Planke...   24.1960  0.100000
# Sauder Camden County Collection Libraries, Plan...  -78.1864  0.145714
# Sauder Camden County Collection Library            -103.4820  0.235000
# Sauder Cornerstone Collection Library               -81.1676  0.233333
# Sauder Facets Collection Library, Sky Alder Finish   -8.5490  0.150000
# Sauder Forest Hills Library with Doors, Woodlan... -418.5480  0.283333
# Sauder Forest Hills Library, Woodland Oak Finish    -70.4900  0.125000
# Sauder Inglewood Library Bookcases                  311.1836  0.130000
# Sauder Mission Library with Doors, Fruitwood Fi... -125.7408  0.263333

# %%
JustBookcases = SalesData.loc[SalesData["Sub-Category"]=="Bookcases"]
JustBookcasesYear = JustBookcases.copy()
JustBookcasesYear['Year'] = JustBookcasesYear["Order Date"].dt.year
Years = JustBookcasesYear.Year.unique()
Regions = JustBookcasesYear.Region.unique()
SegJustBookcasesYear = JustBookcasesYear [['Segment', 'Year', 'Discount', 'Profit', 'Sales', 'Region']]
for year in Years:
  OneYear = SegJustBookcasesYear.loc[SegJustBookcasesYear["Year"]==year]
  NoYear = OneYear[['Segment','Discount', 'Region']]
  for region in Regions:
    OneRegion = NoYear.loc[NoYear['Region']==region]
    BookcasesTotalProfAveDiscount = BookcasesProduct.groupby('Product Name').agg({'Profit':'sum', 'Discount':"mean"})
    YearlySegRegDiscount = OneRegion.groupby('Segment').mean()
    print('\n' + str(year) + ' Bookcase discounts, profits, and sales by customer segment in the ' + region + ' region')
    print(YearlySegRegDiscount)
    print('-'*40)
# Out:
# 2017 Bookcase discounts, profits, and sales by customer segment in the East region
#              Discount
# Segment
# Consumer     0.245455
# Corporate    0.140000
# Home Office  0.233333
# ----------------------------------------
#
# 2017 Bookcase discounts, profits, and sales by customer segment in the Central region
#            Discount
# Segment
# Consumer   0.225714
# Corporate  0.188000
# ----------------------------------------
#
# 2017 Bookcase discounts, profits, and sales by customer segment in the South region
#              Discount
# Segment
# Consumer         0.04
# Corporate        0.20
# Home Office      0.10
# ----------------------------------------
#
# 2017 Bookcase discounts, profits, and sales by customer segment in the West region
#              Discount
# Segment
# Consumer       0.2000
# Corporate      0.2875
# Home Office    0.1000
# ----------------------------------------
#
# 2018 Bookcase discounts, profits, and sales by customer segment in the East region
#            Discount
# Segment
# Consumer   0.215385
# Corporate  0.140000
# ----------------------------------------
#
# 2018 Bookcase discounts, profits, and sales by customer segment in the Central region
#              Discount
# Segment
# Consumer     0.277500
# Corporate    0.263333
# Home Office  0.160000
# ----------------------------------------
#
# 2018 Bookcase discounts, profits, and sales by customer segment in the South region
#              Discount
# Segment
# Consumer          0.1
# Corporate         0.1
# Home Office       0.2
# ----------------------------------------
#
# 2018 Bookcase discounts, profits, and sales by customer segment in the West region
#              Discount
# Segment
# Consumer     0.244118
# Corporate    0.364286
# Home Office  0.120000
# ----------------------------------------
#
# 2019 Bookcase discounts, profits, and sales by customer segment in the East region
#              Discount
# Segment
# Consumer     0.216667
# Corporate    0.340000
# Home Office  0.100000
# ----------------------------------------
#
# 2019 Bookcase discounts, profits, and sales by customer segment in the Central region
#              Discount
# Segment
# Consumer     0.306667
# Corporate    0.160000
# Home Office  0.160000
# ----------------------------------------
#
# 2019 Bookcase discounts, profits, and sales by customer segment in the South region
#           Discount
# Segment
# Consumer       0.1
# ----------------------------------------
#
# 2019 Bookcase discounts, profits, and sales by customer segment in the West region
#              Discount
# Segment
# Consumer     0.241667
# Corporate    0.125000
# Home Office  0.150000
# ----------------------------------------
#
# 2020 Bookcase discounts, profits, and sales by customer segment in the East region
#              Discount
# Segment
# Consumer     0.255556
# Corporate    0.233333
# Home Office  0.180000
# ----------------------------------------
#
# 2020 Bookcase discounts, profits, and sales by customer segment in the Central region
#              Discount
# Segment
# Consumer     0.256667
# Corporate    0.192000
# Home Office  0.235000
# ----------------------------------------
#
# 2020 Bookcase discounts, profits, and sales by customer segment in the South region
#              Discount
# Segment
# Consumer          0.1
# Corporate         0.2
# Home Office       0.0
# ----------------------------------------
#
# 2020 Bookcase discounts, profits, and sales by customer segment in the West region
#            Discount
# Segment
# Consumer   0.269444
# Corporate  0.150000
# ----------------------------------------

# %% [markdown]
# Part 9
# Building basic graphs,
# -matplotlib
# -seaborn

# %%
#Figure 36: Importing MatPlotLib & Seaborn
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
xl=pd.ExcelFile('/Users/ajtan/Documents/GitHub/Classwork/TableauSalesData.xlsx')
SalesData = xl.parse('Orders')

# %%
#Figure 37: Creating "JustTablesYears" Dataframe
JustTables = SalesData.loc[SalesData['Sub-Category']=='Tables']
JustTablesYears = JustTables.copy()
JustTablesYears['Year'] = JustTablesYears['Order Date'].dt.year

# %%
#Figure 39: Basic Pie Chart
JustTableYearSales = JustTablesYears[['Year', 'Sales']].groupby('Year').sum()
#reset_index
JustTableYearSales = JustTableYearSales.reset_index()
#increase size of pie, play with different values
plt.figure(figsize=(6,6))
#title
plt.title('Yearly Table Sales')
#plt.pie tells matplotlib type of graph we need
#JustTablesYearSales.Sales is the dataframe and column that has the data to fill the pie
#JustTablesYearsSales.Year is the dataframe and column that provides labels outside the pie
plt.pie(JustTableYearSales.Sales, labels=JustTableYearSales.Year)
#this is the matplotlib print() function
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Figure 40: Not Resetting Index
JustTableYearSales = JustTablesYears[['Year', 'Sales']].groupby('Year').sum()
#reset_index
#JustTableYearSales = JustTableYearSales.reset_index()
plt.figure(figsize=(6,6))
plt.title('Yearly Table Sales')
plt.pie(JustTableYearSales.Sales, labels=JustTableYearSales.Year)
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j8/qppqqwyn6md61c5w9dqy177m0000gn/T/ipykernel_13013/2601535569.py in <module>
#       5 plt.figure(figsize=(6,6))
#       6 plt.title('Yearly Table Sales')
# ----> 7 plt.pie(JustTableYearSales.Sales, labels=JustTableYearSales.Year)
#       8 plt.show
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
#Figure 41: Basic Bar Chart with Seaborn
JustTableYearSales = JustTablesYear[['Year', 'Sales']].groupby('Year').sum()
JustTableYearSales = JustTableYearSales.reset_index()
#this line tells seaborn what to plot on x and y axis, and which dataframe has the data
barchart1 = sns.barplot(x='Year', y='Sales', data = JustTableYearSales)
#title
barchart1.set_title('Table Sales by Year')
#adding plt.show is optional, though good habit
plt.show()
